# %% [markdown]
# <a href="https://colab.research.google.com/github/nawazgs424-oss/Python-Codes/blob/main/Factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 10

# Performing operations
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("division:", a / b)
print("floor division", a // b )
# Out:
# Addition: 15
# Subtraction: -5
# Multiplication: 50
# division: 0.5
# floor division 0

# %%
def factorial_recursive(n):
    if n == 0 or n == 1:  # base case
        return 1
    else:
        return n * factorial_recursive(n - 1)

# %%
def fibo(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    elif n > 1:
        return fibo(n-2) + fibo(n-1)

# %%
def fibo(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    elif n > 1:
        return fibo(n-2) + fibo(n-1)

# %%
def fibo(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    elif n > 1:
        return fibo(n-2) + fibo(n-1)

# %%
def factorial_recursive(n):
    if n == 0:  # base case
        return 1
    else:
        return n * factorial_recursive(n - 1)

# %%
def factorial_recursive(n):
    if n == 0 or n == 1:  # base case
        return 1
    else:
        return n * factorial_recursive(n - 1)
