# %% [markdown]
# <a href="https://colab.research.google.com/github/nawazgs424-oss/Python-Codes/blob/main/CallFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun1():
  y = 20
  print(x, y)
  print(len(str(x)))
def fun2():
  z = 30
  print(x, z)
  print(len(str(x)))

x = 10
fun2()
print(len(str(x)))
fun1()
# Out:
# 10 30
# 2
# 2
# 10 20
# 2

# %%
def fun1():
  a = 45
  print(a)
  print(id(a))
def fun2():
  a = 90
  print(a)
  print(id(a))
fun2()
fun1()
# Out:
# 90
# 11644936
# 45
# 11643496

# %%
a = 10

b = 20

c = 30


globals ()['a'] = 25

globals ()['b'] = 50

globals ()['c'] = 75
print(a, b, c)
# Out:
# 25 50 75

# %%
def fun():
    a = 10
    b = 20
    c = 30
    locals()['a'] = 25
    locals()['b'] = 50
    locals()['c'] = 75
    print(a, b, c)

fun()
# Out:
# 10 20 30

# %%
# modf1.py
def funf1() :
print('The ability to speak several languages is an asset...')
print('ability to keep your mouth shut in any language is priceless')
# modf2.py
def funf2):
print('If you cut off your left arm...')
print('then your right arm would be left')
# modf3.py
def funf3() :
print( 'Alcohol is a solution!")
# modc1.py
def func1() :
print( Light travels faster than sound... )
print('People look intelligent, till they open their mouth')
# modc2.py
def func2() :
print('There is no physical evidence to say that today is Tuesday...')
print(We have to trust someone who kept the count since first day')
# modc3.py
def func3() :
print('We spend five days a week pretending to be someone else...')
print(in order to spend two days being who we are')
# client.py
import messages.funny.modf1
import messages.funny.modf2
import messages.funny.modf3
import messages.curt.modc1
import messages.curt.modc2
messages.funnv.modf1. funf1()
messages.funny.modf2. funf2()
messages.funny.modf3. funf3()
messages.curt.modc1. func1()
messages.curt.modc2. func2()
# Out:
#   File "/tmp/ipython-input-2287454012.py", line 6
#     def funf2):
#              ^
# SyntaxError: unmatched ')'

# %%
# modf1.py
def funf1():
    print('The ability to speak several languages is an asset...')
    print('ability to keep your mouth shut in any language is priceless')
# modf2.py
def funf2():
    print('If you cut off your left arm...')
    print('then your right arm would be left')
# modf3.py
def funf3():
    print('Alcohol is a solution!')
# modc1.py
def func1():
    print('Light travels faster than sound...')
    print('People look intelligent, till they open their mouth')
# modc2.py
def func2():
    print('There is no physical evidence to say that today is Tuesday...')
    print('We have to trust someone who kept the count since first day')
# modc3.py
def func3():
    print('We spend five days a week pretending to be someone else...')
    print('in order to spend two days being who we are')

# client.py
funf1()
funf2()
funf3()
func1()
func2()
# Out:
# The ability to speak several languages is an asset...
# ability to keep your mouth shut in any language is priceless
# If you cut off your left arm...
# then your right arm would be left
# Alcohol is a solution!
# Light travels faster than sound...
# People look intelligent, till they open their mouth
# There is no physical evidence to say that today is Tuesday...
# We have to trust someone who kept the count since first day

# %%
# Define the functions directly in the cell
def funf1():
    print('The ability to speak several languages is an asset...')
    print('ability to keep your mouth shut in any language is priceless')

def funf2():
    print('If you cut off your left arm...')
    print('then your right arm would be left')

def funf3():
    print('Alcohol is a solution!')

def func1():
    print('Light travels faster than sound...')
    print('People look intelligent, till they open their mouth')

def func2():
    print('There is no physical evidence to say that today is Tuesday...')
    print('We have to trust someone who kept the count since first day')

def func3():
    print('We spend five days a week pretending to be someone else...')
    print('in order to spend two days being who we are')

# Call the functions
funf1()
funf2()
funf3()
func1()
func2()
func3()
# Out:
# The ability to speak several languages is an asset...
# ability to keep your mouth shut in any language is priceless
# If you cut off your left arm...
# then your right arm would be left
# Alcohol is a solution!
# Light travels faster than sound...
# People look intelligent, till they open their mouth
# There is no physical evidence to say that today is Tuesday...
# We have to trust someone who kept the count since first day
# We spend five days a week pretending to be someone else...
# in order to spend two days being who we are

# %%
# Define the functions directly in the cell
def funf1():
    print('The ability to speak several languages is an asset...')
    print('ability to keep your mouth shut in any language is priceless')

def funf2():
    print('If you cut off your left arm...')
    print('then your right arm would be left')

def funf3():
    print('Alcohol is a solution!')

def func1():
    print('Light travels faster than sound...')
    print('People look intelligent, till they open their mouth')

def func2():
    print('There is no physical evidence to say that today is Tuesday...')
    print('We have to trust someone who kept the count since first day')

def func3():
    print('We spend five days a week pretending to be someone else...')
    print('in order to spend two days being who we are')

# Call the functions
funf1()
funf2()
funf3()
func1()
func2()
func3()
# Out:
# The ability to speak several languages is an asset...
# ability to keep your mouth shut in any language is priceless
# If you cut off your left arm...
# then your right arm would be left
# Alcohol is a solution!
# Light travels faster than sound...
# People look intelligent, till they open their mouth
# There is no physical evidence to say that today is Tuesday...
# We have to trust someone who kept the count since first day
# We spend five days a week pretending to be someone else...
# in order to spend two days being who we are
