# %% [markdown]
# <a href="https://colab.research.google.com/github/nawazgs424-oss/Python-Codes/blob/main/Basics3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a,  b = 88, 99
a, b = b, a
print(a,b)
# Out:
# 99 88

# %%
    a = 10
    b = 20
    result = a + b
    print("Inside function: result =", result)
# Out:
# Inside function: result = 30

# %%
a_string = "name of a animal"
print("clockwise",a_stringbool[0])
print("anticlockwise",a_string[3])
print(bool(a_string)
# Out:
#   File "/tmp/ipython-input-1994346045.py", line 4
#     print(bool(a_string)
#                         ^
# SyntaxError: incomplete input

# %%
x,y,=input("20,30:").split()
print

# %%
name, age, country = data.split()

print("Name:", name)
print("Age:", age)
print("Country:", country)

# %%
#printing
